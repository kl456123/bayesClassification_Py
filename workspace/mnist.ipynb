# %%
# !python fully_connected_feed.py
# Out:
# Extracting dataset/mnist/train-images-idx3-ubyte.gz
# Extracting dataset/mnist/train-labels-idx1-ubyte.gz
# Extracting dataset/mnist/t10k-images-idx3-ubyte.gz
# Extracting dataset/mnist/t10k-labels-idx1-ubyte.gz
# Step 0: loss = 2.30 (0.027 sec)
# Step 100: loss = 2.29 (0.002 sec)
# Step 200: loss = 2.27 (0.001 sec)
# Step 300: loss = 2.25 (0.002 sec)
# Step 400: loss = 2.20 (0.002 sec)
# Step 500: loss = 2.07 (0.002 sec)
# Step 600: loss = 2.02 (0.002 sec)
# Step 700: loss = 1.68 (0.002 sec)
# Step 800: loss = 1.36 (0.002 sec)
# Step 900: loss = 1.13 (0.002 sec)
# Training Data Eval:
#   Num examples: 55000  Num correct: 38546  Precision @ 1: 0.7008
# Validation Data Eval:
#   Num examples: 5000  Num correct: 3547  Precision @ 1: 0.7094
# Test Data Eval:
#   Num examples: 10000  Num correct: 7157  Precision @ 1: 0.7157
# Step 1000: loss = 0.83 (0.009 sec)
# Step 1100: loss = 1.00 (0.116 sec)
# Step 1200: loss = 0.89 (0.001 sec)
# Step 1300: loss = 0.61 (0.001 sec)
# ...
